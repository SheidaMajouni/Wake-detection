# %%
import os
import pandas as pd
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_23851/3571106454.py", line 2, in <module>
#     import pandas as pd
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/arrays/arrow/array.py", line 50, in <module>
#     from pandas.core import (
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/ops/__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/ops/array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/compat/_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/numexpr/__init__.py", line 26, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %%
# parameters 

INPUT_PATH = "processed_ts/train"
OUTPUT_PATH = "processed_ts/train_wake_intervals"

TIME_COL = "t_s"
VALUE_COL = "z_m"

BASELINE_WINDOW_S = 60.0
NOISE_WINDOW_S = 30.0
HIGH_Z = 2.5
LOW_Z = 1.2
MIN_DURATION_S = 2.0
MERGE_GAP_S = 1.0

# %%
def _rolling_median(arr: pd.Series, win: int) -> pd.Series:
    return arr.rolling(win, min_periods=1, center=True).median()

def _rolling_mad(arr: pd.Series, win: int) -> pd.Series:
    med = arr.rolling(win, min_periods=1, center=True).median()
    mad = (arr - med).abs().rolling(win, min_periods=1, center=True).median()
    sigma = mad * 1.4826
    sigma = sigma.replace(0, None).bfill().ffill().fillna(1e-6)
    return sigma

def detect_wakes_rule_based(df: pd.DataFrame) -> pd.DataFrame:
    t = df[TIME_COL].values.astype(float)
    x = df[VALUE_COL].astype(float)

    dt = pd.Series(t).diff().median()
    fs = 1.0 / dt

    bw = max(int(round(BASELINE_WINDOW_S * fs)), 3)
    nw = max(int(round(NOISE_WINDOW_S * fs)), 3)

    baseline = _rolling_median(x, bw)
    detrended = x - baseline
    sigma = _rolling_mad(detrended, nw)
    z = detrended / sigma

    in_wake = False
    start_idx = None
    intervals = []
    for i, zi in enumerate(z):
        if not in_wake and zi >= HIGH_Z:
            in_wake = True
            start_idx = i
        elif in_wake and zi <= LOW_Z:
            intervals.append((start_idx, i))
            in_wake = False

    if in_wake:
        intervals.append((start_idx, len(z)-1))

    rows = []
    for s, e in intervals:
        seg = df.iloc[s:e+1]
        seg_z = z.iloc[s:e+1]
        rows.append(dict(
            start_s=seg[TIME_COL].iloc[0],
            end_s=seg[TIME_COL].iloc[-1],
            duration_s=seg[TIME_COL].iloc[-1] - seg[TIME_COL].iloc[0],
            peak_value=seg[VALUE_COL].max(),
            peak_z=seg_z.max()
        ))
    return pd.DataFrame(rows)

def process_file(in_path, out_path):
    df = pd.read_csv(in_path)
    intervals_df = detect_wakes_rule_based(df)
    os.makedirs(os.path.dirname(out_path), exist_ok=True)
    intervals_df.to_csv(out_path, index=False)
#     print(f"Saved: {out_path}")

def main():
    if os.path.isfile(INPUT_PATH):
        # single file
        out_file = os.path.join(OUTPUT_PATH, os.path.basename(INPUT_PATH).replace(".csv", "_wakes.csv"))
        process_file(INPUT_PATH, out_file)
    else:
        # folder -> mirror structure
        for root, _, files in os.walk(INPUT_PATH):
            for fn in files:
                if not fn.endswith(".csv"): continue
                in_fp = os.path.join(root, fn)
                rel = os.path.relpath(in_fp, INPUT_PATH)
                out_fp = os.path.join(OUTPUT_PATH, rel.replace(".csv", "_wakes.csv"))
                process_file(in_fp, out_fp)

if __name__ == "__main__":
    main()
# Out:
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1639881300-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1700342400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1716357000-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/hecate_strait_banks_island_deadman_islet-1722637200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1635389340-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1634832240-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1645749300-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_01-1642877400-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1638643800-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1722349200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/hecate_strait_browning_entrance_sentinel_islet-1698931200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1636072500-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_07-1642631700-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_03-1644092400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1718664600-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1700845500-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1724375100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1644003300-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_02-1639672500-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1724086200-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1645264200-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1711553700-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1714279800-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1727876100-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1642301400-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_02-1634916900-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_02-1644455100-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1642781100-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/lewis_passage_fin_island_howard_islet-1720300800-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_02-1637526900-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1710528600-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1645630500-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_01-1634472300-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1642557000-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_05-1647977700-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1715951100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1719251400-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1642802700-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1646067000-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1641481500-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1634832300-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_09-1647120900-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1646929200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1700078700-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1729732800-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_06-1638176700-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1636499100-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1721253000-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1648177500-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1702650900-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1707703500-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/principe_channel_wheeler_island-1715091600-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_03-1647017400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1711975800-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1714483200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1714757700-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1635963600-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1636844700-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1707275100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1644965400-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1643139300-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_02-1644365100-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1719045300-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1635009600-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_06-1642532700-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1715698200-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1706624400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_02-1640970300-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1709257800-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1714771200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1634593740-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/wright_sound_gil_island-fisherman_cove-1718158800-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_02-1640965800-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1710945300-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1637684400-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_05-1636151700-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_09-1645472100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1635613500-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1704069300-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1643587500-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1715171700-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_01-1649975700-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1718503500-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1716985200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/wright_sound_gil_island-fisherman_cove-1724038500-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_05-1648215300-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_09-1648245900-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_06-1635743100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_05-1646601600-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1708653000-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1723646100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1649235900-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_05-1648065000-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_06-1635439800-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1643514600-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1713834300-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/wright_sound_gil_island-fisherman_cove-1710100200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1720880400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1730764200-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1640284500-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1701201000-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1644779100-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1711896600-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_01-1639172100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1717680000-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1707617100-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1732207800-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1728408000-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1634487540-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_06-1646435100-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_03-1641663300-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1649116200-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/wright_sound_gil_island-fisherman_cove-1713311400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_07-1646988600-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_09-1642594800-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1644965400-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_02-1634456100-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1706279700-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1647181200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/douglas_channel_hartley_bay_halsey_point-1717691700-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1716798900-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1637697900-v3-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1643583000-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_05-1634419200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_03-1643845800-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1639516800-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/principe_channel_wheeler_island-1702466400-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1709213700-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1720456500-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/douglas_channel_hartley_bay_halsey_point-1712864100-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/wright_sound_gil_island-fisherman_cove-1721173800-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1645555800-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1645501800-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/metlakatla_01-1640504100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/cowichan_lake_02-1617387000-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1713535500-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1635212040-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1726235400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1717334400-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1648917300-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/hecate_strait_banks_island_deadman_islet-1706317500-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1646243400-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1642461600-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1723149300-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/hecate_strait_banks_island_deadman_islet-1710764400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1731457200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/cowichan_lake_01-1619385000-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/wright_sound_gil_island-fisherman_cove-1723503900-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/lewis_passage_fin_island_howard_islet-1709597100-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1642531800-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1718946300-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1645718700-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1643559600-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1645752000-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1640900100-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/douglas_channel_hartley_bay_halsey_point-1717172400-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_05-1647527700-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1727731200-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1724597400-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1724608200-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1640808300-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/hecate_strait_banks_island_deadman_islet-1702810200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1716780000-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/douglas_channel_kitkiata_inlet_helen_point-1722916200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/principe_channel_wheeler_island-1701250500-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1702650000-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/douglas_channel_hartley_bay_halsey_point-1713317700-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_02-1640639100-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1638836400-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1712451900-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1645390200-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_01-1648249500-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1723134900-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/cowichan_lake_01-1616712000-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/lewis_passage_fin_island_howard_islet-1702076700-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1719454800-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1714410300-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_01-1638714000-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1703181000-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1706493000-v3-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_09-1638286500-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1648747200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1720187400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1710135300-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/metlakatla_01-1640885700-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1643138400-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/metlakatla_01-1640724600-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1642686600-v3-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_06-1641765900-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1648424100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1713016200-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1706277900-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1731800100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_02-1641658800-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1645405500-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1647135300-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/lewis_passage_fin_island_howard_islet-1700488200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1645181400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_02-1636245300-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_05-1644358800-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1642899000-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1642883700-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_02-1640810100-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1641484200-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/douglas_channel_kitkiata_inlet_helen_point-1720197300-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1647877800-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/principe_channel_wheeler_island-1716879900-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1712537400-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1635209340-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/hecate_strait_banks_island_deadman_islet-1722402300-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1636590000-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_01-1643135700-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1717073400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1643568600-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/douglas_channel_hartley_bay_halsey_point-1719191100-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1723735200-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1704333000-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1730782200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_06-1643401200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/principe_channel_wheeler_island-1724268900-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_01-1635717000-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/douglas_channel_kitkiata_inlet_helen_point-1719155100-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1725973500-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1643644200-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1639700400-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1715050200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/lewis_passage_fin_island_howard_islet-1715146500-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1715433600-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1642025100-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/metlakatla_01-1641592200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/douglas_channel_kitkiata_inlet_helen_point-1723508400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1646518800-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_06-1637425200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1638635700-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1644682800-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1717252500-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1720675200-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/hecate_strait_banks_island_deadman_islet-1723071000-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1646508000-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1646068800-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_09-1637346900-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1712062200-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_05-1635001500-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1726664700-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1718328900-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_05-1635527100-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1725455100-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/principe_channel_wheeler_island-1716448800-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1712751600-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_01-1642988100-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/douglas_channel_hartley_bay_halsey_point-1714416600-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1710817500-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1635650400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_09-1646178600-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1722776700-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1638562800-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1719687000-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1732157400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1645041900-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_09-1634747700-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_05-1642373400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1720271100-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1646872500-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1637233500-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1706040300-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_05-1643493000-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1726301100-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1645031100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_06-1639788600-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1637256000-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1710528600-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_06-1643227500-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1719332400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1648226100-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_09-1635726900-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_02-1643484900-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1710300900-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1636040100-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1637103900-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1726397400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_01-1639483500-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1701903900-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1643575800-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_01-1642024200-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1635211140-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1636919400-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/wright_sound_gil_island-fisherman_cove-1720890300-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_05-1649715600-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1711480800-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_03-1647022800-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1711241400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1719936300-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1706277900-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_06-1648145100-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1715716200-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_05-1642358100-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/douglas_channel_hartley_bay_halsey_point-1716842100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1703087400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1642717200-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1729799400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1638733800-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/douglas_channel_hartley_bay_halsey_point-1720932600-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_06-1643061000-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1643044800-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1638667200-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1635174240-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1719412500-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/douglas_channel_kitkiata_inlet_helen_point-1700919300-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_02-1641751500-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1646769000-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/kitimat_arm_bish_cove-1723048500-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1636994100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/douglas_channel_hartley_bay_halsey_point-1714957500-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1713097200-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1703860500-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1718003100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1639511400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1714682100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_01-1646667300-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_06-1634593800-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1637166000-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/tsouke_02-1639757100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_01-1649936100-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_07-1638637500-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_01-1636994100-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1721141400-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_01-1646853600-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1634857440-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/wright_sound_gil_island-fisherman_cove-1722097200-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1638379200-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_05-1649725500-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1731793800-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_07-1637421600-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_foulger_creek-1726372200-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/howe_sound_defence_island_north-1729129800-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/bcip_04-1643068200-v2-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1642374300-timeseries-1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1639858800-v1-labeled_wakes.csv
# Saved: processed_ts/train_wake_intervals/prince_rupert_02-1634795340-v1-labeled_wakes.csv
